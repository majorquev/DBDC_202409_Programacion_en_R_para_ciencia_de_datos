# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/DBDC_202409_Programacion_en_R_para_ciencia_de_datos/blob/main/Clases/C4/01_Cruce_de_tablas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parte 2: Manipulación de tablas en R (Parte II)
#
# **Autor:** Miguel Jorquera Viguera<br>
# **E-mail:** majorquev@gmail.com<br>
# **Ayudante:** Rodrigo Morales<br>
# **E-mail ayudante:** rumorale1@gmail.com
#
#
#
# Recurso de referencia: https://es.r4ds.hadley.nz/
#
#
# ## 1. Cruce entre tablas (joins)
#
# Otras funciones de gran utilidad son los joins. <br>
# Un join es básicamente un cruce entre dos tablas a través de uno o varios campos (columnas) de interés. En la librería _dplyr_ contamos con diferentes funciones para generar joins entre dos tablas. Entre los tipos de joins más usuales destacan los del tipo _inner, left, right_, entre otros. <br>
#
# Supongamos que queremos cruzar las siguientes tablas x e y. Entonces, una manera de visualizer el comportamiento de los diferentes tipos de “joins” es la siguiente.
#
#
# ![Picture1.png](data:image/png;base64,...)
#
#
# ### Ejemplo:

# %%
library(dplyr) # Extender funcionalidad de "base R" por ejemplo, el paquete "stats"
# En este caso, filter es un método de "dplyr" que se ubicará "por sobre" el método de Base R "filter"

# %%
data(band_members) # Carga de datos "nativos" o built-in de R
data(band_instruments)

band_members
band_instruments

# %%
# left_join(x,y,by) # x: tabla izq, y : tabla der.
# se puede o no expicitar (como ya sabemos) el nombre de los parámetros

# %%
# Usando %>%

# select A.name, A.band, B.plays
# from band_members A
# left join band_instruments B
# on A.name = B .name

# %%
# Si realizamos un cruce tipo right_join
band_members %>%


# un right join es equivalente a un left join invirtiendo el orden de las tablas.

# %% [markdown]
# ¿Qué ocurre si los campos por los que se esea hacer el cruce no tienen los mismos nombres?

# %%
band_instruments_2 <- band_instruments
colnames(band_instruments_2) <- c("nombre", "plays")
band_instruments_2

# %%
#Sintaxis

# %%
# Si queremos cruzar dos tablas por más de un campo, podemos declarar estas columnas de la siguiente manera
## Como ejemplo, la tabla 'habilidades' representa las habilidades de distintos 'perritos', mientras que la tabla perritos contiene características de cada animal (perrito)

habilidades <- data.frame(
    raza      = c("pastor_aleman","poddle","poddle","shiba inu","mestizo","mestizo","poddle","mestizo","pastor_aleman"),
    nombre    = c("rex","bobi","pelusa","arya","akira","akira","bobi","akira","rex"),
    dueño     = c("pedro","javier","camila","pedro","pabla","pabla","javier","pabla","daniela"),
    habilidad = c("ve_tv","trae_pelota","saluda","se_hace_muerto","trae_pelota","se_hace_muerto","juega_con_sombras","ve_tv","sigue_ciclistas")
)

habilidades %>%
    arrange(dueño)

# %%
perritos <- data.frame(
    raza_perrito       = c("pastor_aleman","poddle","poddle","shiba inu","mestizo","pastor_aleman"),
    nombre_perrito     = c("rex","bobi","pelusa","arya","akira","rex"),
    dueño_perrito      = c("pedro","javier","camila","pedro","pabla","daniela"),
    edad               = c(5,13,12,1,3,6),
    tamaño             = c("grande","pequeño","pequeño","mediano","grande","grande"),
    color              = c("negro","blanco","blanco","café","café","negro"),
    sexo               = c("M","M","H","H","M","M"),
    duerme_cama_propia = c(T,F,T,T,F,T)
)

perritos

# %%
# Es posible observar que cada registro de la tabla `habilidades` le corresponde un único registro en la tabla
# perritos, a través de la combinación de los campos raza, nombre y dueño.

# Ubicar las edades de aquellos perritos que tienen como habilidad "traer la pelota"
